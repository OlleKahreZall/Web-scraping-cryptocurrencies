# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %%
# Import and visualize the data
df = pd.read_csv('cryptocurrencies_top-100.csv')
df
# Out:
#                 date       open       high        low      close       volume  \
# 0       Dec 02, 2020  18 801,74  19 308,33  18 347,72  19 201,09  37387697139
# 1       Dec 01, 2020  19 633,77  19 845,98  18 321,92  18 803,00  49633658712
# 2       Dec 02, 2020     587,26     604,02     578,74     598,35  16883292129
# 3       Nov 30, 2020  18 178,32  19 749,26  18 178,32  19 625,84  47728480399
# 4       Dec 01, 2020     615,07     635,16     571,75     587,32  27178964465
# ...              ...        ...        ...        ...        ...          ...
# 104227  Nov 28, 2017      65,67      65,70      50,29      54,47     22958800
# 104228  Nov 27, 2017      66,30      70,60      63,82      65,89     22995100
# 104229  Nov 26, 2017      94,20      94,25      65,90      66,12     20896400
# 104230  Nov 25, 2017      69,35     104,84      68,77      94,22     45941900
# 104231  Nov 24, 2017      61,71      74,44      61,71      69,30     23322800
#
#           market_cap   cryptocurrency
# 0       356381007571          bitcoin
# 1       348976597318          bitcoin
# 2        68015797685         ethereum
# 3       364229729426          bitcoin
# 4        66754367842         ethereum
# ...              ...              ...
# 104227             0  bitcoin-diamond
# 104228             0  bitcoin-diamond
# 104229             0  bitcoin-diamond
# 104230             0  bitcoin-diamond
# 104231             0  bitcoin-diamond
#
# [104232 rows x 8 columns]

# %%
# Count the total number of cryptocurrencies in the dataframe
df['cryptocurrency'].unique()
count=0
for i in df['cryptocurrency'].unique():
    count+=1
print(count)
# Out:
# 100

# %%
# Check all the rows for, in this case, bitcoin.
df[df['cryptocurrency'] == 'bitcoin']
# Out:
#               date       open       high        low      close       volume  \
# 0     Dec 02, 2020  18 801,74  19 308,33  18 347,72  19 201,09  37387697139
# 1     Dec 01, 2020  19 633,77  19 845,98  18 321,92  18 803,00  49633658712
# 3     Nov 30, 2020  18 178,32  19 749,26  18 178,32  19 625,84  47728480399
# 7     Nov 29, 2020  17 719,63  18 283,63  17 559,12  18 177,48  31133957704
# 8     Nov 28, 2020  17 112,93  17 853,94  16 910,65  17 717,42  32601040734
# ...            ...        ...        ...        ...        ...          ...
# 5411  May 03, 2013     106,25     108,13      79,10      97,75            0
# 5412  May 02, 2013     116,38     125,60      92,28     105,21            0
# 5413  May 01, 2013     139,00     139,89     107,72     116,99            0
# 5414  Apr 30, 2013     144,00     146,93     134,05     139,00            0
# 5417  Apr 29, 2013     134,44     147,49     134,00     144,54            0
#
#         market_cap cryptocurrency
# 0     356381007571        bitcoin
# 1     348976597318        bitcoin
# 3     364229729426        bitcoin
# 7     337336592123        bitcoin
# 8     328782832212        bitcoin
# ...            ...            ...
# 5411    1085995169        bitcoin
# 5412    1168517495        bitcoin
# 5413    1298954594        bitcoin
# 5414    1542813125        bitcoin
# 5417    1603768865        bitcoin
#
# [2775 rows x 8 columns]

# %%
# Data cleaning.
uncleaned_columns = list(df)[1:-2] 
for column in uncleaned_columns:
    df[column] = df[column].str.replace(',', '.')
    df[column] = df[column].str.replace('\xa0', '').astype(float)

# %%
# Check to see if everything looks correct in the  dataframe.
df.head(1000)
# Out:
#              date      open      high       low     close        volume  \
# 0    Dec 02, 2020  18801.74  19308.33  18347.72  19201.09  3.738770e+10
# 1    Dec 01, 2020  19633.77  19845.98  18321.92  18803.00  4.963366e+10
# 2    Dec 02, 2020    587.26    604.02    578.74    598.35  1.688329e+10
# 3    Nov 30, 2020  18178.32  19749.26  18178.32  19625.84  4.772848e+10
# 4    Dec 01, 2020    615.07    635.16    571.75    587.32  2.717896e+10
# ..            ...       ...       ...       ...       ...           ...
# 995  Jul 18, 2019   9698.50  10736.84   9376.80  10666.48  2.518702e+10
# 996  Jul 17, 2019   9471.21   9963.13   9163.13   9693.80  2.456992e+10
# 997  Jul 29, 2019    211.12    213.93    208.76    211.27  5.485191e+09
# 998  Jul 28, 2019    207.41    212.04    202.25    211.19  5.504888e+09
# 999  Jul 27, 2019    219.62    223.52    204.90    207.41  6.257704e+09
#
#        market_cap cryptocurrency
# 0    356381007571        bitcoin
# 1    348976597318        bitcoin
# 2     68015797685       ethereum
# 3    364229729426        bitcoin
# 4     66754367842       ethereum
# ..            ...            ...
# 995  190129918121        bitcoin
# 996  172777250515        bitcoin
# 997   22627969069       ethereum
# 998   22616386468       ethereum
# 999   22208955063       ethereum
#
# [1000 rows x 8 columns]

# %%
# Select the name of all cryptocurrencies and store them in a list
all_names = df['cryptocurrency'].unique()
print(f'The top 10 cryptocurrencies:{all_names[:10]}')
# Out:
# The top 10 cryptocurrencies:['bitcoin' 'ethereum' 'xrp' 'tether' 'litecoin' 'chainlink' 'bitcoin-cash'
#  'cardano' 'polkadot-new' 'binance-coin']

# %%
# Lists of the columns 'close', 'volume' and 'market_cap' are generated by looping over all cryptocurrencies
close = []
volume = []
market_cap = []

for cryptocurrency in all_names:
    close.append(df.loc[df['cryptocurrency'] == cryptocurrency]["close"].tolist())
    volume.append(df.loc[df['cryptocurrency'] == cryptocurrency]["volume"].tolist())
    market_cap.append(df.loc[df['cryptocurrency'] == cryptocurrency]["market_cap"].tolist())

# %%
# Plot the daily closed values for the 3 biggest cryptocurrencies based on their market cap.

x_axis = ['Apr 2013', 'Sep 2014', 'Jan 2016', 'Jun 2017', 'Oct 2019', 'Mar 2020']

fig, ax = plt.subplots()
ax.plot(range(len(close[0])), close[0][::-1], label = 'Bitcoin', color = 'red') 
ax.plot(range(len(close[0])-len(close[1]), len(close[0])), close[1][::-1], label = 'Ethereum', color = 'blue')
ax.plot(range(len(close[0])-len(close[2]), len(close[0])), close[2][::-1], label = 'XRP', color = 'black') 

legend = ax.legend(loc='upper left', fontsize='large')
plt.xlabel('Time')
plt.ylabel('USD')
plt.rcParams["figure.figsize"] = (17,5)
fig.suptitle('The daily closed values of the 3 biggest cryptocurrencies', fontsize=20) 

labels = [item.get_text() for item in ax.get_xticklabels()]
for i in range(len(x_axis)):
    labels[i+1] = x_axis[i]
ax.set_xticklabels(labels)

plt.show()

# %%
# Plot the daily volume for the 3 biggest cryptocurrencies based on their market cap.

fig, ax = plt.subplots()
ax.plot(range(len(volume[0])), volume[0][::-1], label = 'Bitcoin', color = 'red') 
ax.plot(range(len(volume[0])-len(volume[1]), len(volume[0])), volume[1][::-1], label = 'Ethereum', color = 'blue')
ax.plot(range(len(volume[0])-len(volume[2]), len(volume[0])), volume[2][::-1], label = 'XRP', color = 'black') 

legend = ax.legend(loc='upper left', fontsize='large')
plt.xlabel('Time')
plt.ylabel('USD')
#plt.title()
fig.suptitle('The daily volumes of the 3 biggest cryptocurrencies', fontsize=20) 
plt.rcParams["figure.figsize"] = (17,5)

labels = [item.get_text() for item in ax.get_xticklabels()]
for i in range(len(x_axis)):
    labels[i+1] = x_axis[i]
ax.set_xticklabels(labels)

plt.show()

# %%
# Plot the daily market cap for the 3 biggest cryptocurrencies based on their market cap.

fig, ax = plt.subplots()
ax.plot(range(len(market_cap[0])), market_cap[0][::-1], label = 'Bitcoin', color = 'red') 
ax.plot(range(len(market_cap[0])-len(market_cap[1]), len(market_cap[0])), market_cap[1][::-1], label = 'Ethereum', color = 'blue')
ax.plot(range(len(market_cap[0])-len(market_cap[2]), len(market_cap[0])), market_cap[2][::-1], label = 'XRP', color = 'black')

legend = ax.legend(loc='upper left', fontsize='large')
plt.xlabel('Time')
plt.ylabel('USD')
#plt.title()
fig.suptitle('The daily market caps of the 3 biggest cryptocurrencies', fontsize=20) 
plt.rcParams["figure.figsize"] = (17,5)

labels = [item.get_text() for item in ax.get_xticklabels()]
for i in range(len(x_axis)):
    labels[i+1] = x_axis[i]
ax.set_xticklabels(labels)

plt.show()
